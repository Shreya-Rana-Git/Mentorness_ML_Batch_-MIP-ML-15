# %%
import pandas as pd
import pickle
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('data.xlsx')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
X = df.drop('target', axis=1)
Y = df['target']

# %%
models=[  'KNN' , 'DecisionTreeClassifier' , 'RandomForest' ]

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
for model in models:
    md = pickle.load(open(model,'rb'))
    md.fit(X,Y)
    print(model)
    print('\n--------------------------------------------------\n')
    print(f' accuracy score: {100*round(accuracy_score(Y,md.predict(X)),4)} % \n')
    print(f' Confusion Matrix:\n {confusion_matrix(Y,md.predict(X))}\n')
    print(f' Classification Report:\n {classification_report(Y,md.predict(X))}')
    print('\n--------------------------------------------------\n')
    print('\n\n\n')
# Out:
# KNN
#
# --------------------------------------------------
#
#  accuracy score: 70.19999999999999 %
#
#  Confusion Matrix:
#  [[ 90  48]
#  [ 42 122]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.68      0.65      0.67       138
#            1       0.72      0.74      0.73       164
#
#     accuracy                           0.70       302
#    macro avg       0.70      0.70      0.70       302
# weighted avg       0.70      0.70      0.70       302
#
#
# --------------------------------------------------
#
#
#
#
#
# DecisionTreeClassifier
#
# --------------------------------------------------
#
#  accuracy score: 82.45 %
#
#  Confusion Matrix:
#  [[109  29]
#  [ 24 140]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.79      0.80       138
#            1       0.83      0.85      0.84       164
#
# ...
